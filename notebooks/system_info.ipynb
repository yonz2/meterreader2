# %%
import psutil
import platform
from datetime import datetime

# %%
def get_size(bytes, suffix="B"):
    """
    Scale bytes to its proper format
    e.g:
        1253656 => '1.20MB'
        1253656678 => '1.17GB'
    """
    factor = 1024
    for unit in ["", "K", "M", "G", "T", "P"]:
        if bytes < factor:
            return f"{bytes:.2f}{unit}{suffix}"
        bytes /= factor

# %%
print("="*40, "System Information", "="*40)
uname = platform.uname()
print(f"System: {uname.system}")
print(f"Node Name: {uname.node}")
print(f"Release: {uname.release}")
print(f"Version: {uname.version}")
print(f"Machine: {uname.machine}")
print(f"Processor: {uname.processor}")

# let's print CPU information
print("="*40, "CPU Info", "="*40)
# number of cores
print("Physical cores:", psutil.cpu_count(logical=False))
print("Total cores:", psutil.cpu_count(logical=True))
# CPU frequencies
cpufreq = psutil.cpu_freq()
print(f"Max Frequency: {cpufreq.max:.2f}Mhz")
print(f"Min Frequency: {cpufreq.min:.2f}Mhz")
print(f"Current Frequency: {cpufreq.current:.2f}Mhz")
# CPU usage
print("CPU Usage Per Core:")
for i, percentage in enumerate(psutil.cpu_percent(percpu=True, interval=1)):
    print(f"Core {i}: {percentage}%")
print(f"Total CPU Usage: {psutil.cpu_percent()}%")

# Memory Information
print("="*40, "Memory Information", "="*40)
# get the memory details
svmem = psutil.virtual_memory()
print(f"Total: {get_size(svmem.total)}")
print(f"Available: {get_size(svmem.available)}")
print(f"Used: {get_size(svmem.used)}")
print(f"Percentage: {svmem.percent}%")
print("="*20, "SWAP", "="*20)
# get the swap memory details (if exists)
swap = psutil.swap_memory()
print(f"Total: {get_size(swap.total)}")
print(f"Free: {get_size(swap.free)}")
print(f"Used: {get_size(swap.used)}")
print(f"Percentage: {swap.percent}%")

# Disk Information
print("="*40, "Disk Information", "="*40)
print("Partitions and Usage:")
# get all disk partitions
partitions = psutil.disk_partitions()
for partition in partitions:
    print(f"=== Device: {partition.device} ===")
    print(f"  Mountpoint: {partition.mountpoint}")
    print(f"  File system type: {partition.fstype}")
    try:
        partition_usage = psutil.disk_usage(partition.mountpoint)
    except PermissionError:
        # this can be catched due to the disk that
        # isn't ready
        continue
    print(f"  Total Size: {get_size(partition_usage.total)}")
    print(f"  Used: {get_size(partition_usage.used)}")
    print(f"  Free: {get_size(partition_usage.free)}")
    print(f"  Percentage: {partition_usage.percent}%")
# get IO statistics since boot
disk_io = psutil.disk_io_counters()
print(f"Total read: {get_size(disk_io.read_bytes)}")
print(f"Total write: {get_size(disk_io.write_bytes)}")

# Network information
print("="*40, "Network Information", "="*40)
# get all network interfaces (virtual and physical)
if_addrs = psutil.net_if_addrs()
for interface_name, interface_addresses in if_addrs.items():
    for address in interface_addresses:
        print(f"=== Interface: {interface_name} ===")
        if str(address.family) == 'AddressFamily.AF_INET':
            print(f"  IP Address: {address.address}")
            print(f"  Netmask: {address.netmask}")
            print(f"  Broadcast IP: {address.broadcast}")
        elif str(address.family) == 'AddressFamily.AF_PACKET':
            print(f"  MAC Address: {address.address}")
            print(f"  Netmask: {address.netmask}")
            print(f"  Broadcast MAC: {address.broadcast}")
# get IO statistics since boot
net_io = psutil.net_io_counters()
print(f"Total Bytes Sent: {get_size(net_io.bytes_sent)}")
print(f"Total Bytes Received: {get_size(net_io.bytes_recv)}")
# Out:
# ======================================== System Information ========================================
# System: Linux
# Node Name: bute
# Release: 6.8.0-51-generic
# Version: #52-Ubuntu SMP PREEMPT_DYNAMIC Thu Dec  5 13:09:44 UTC 2024
# Machine: x86_64
# Processor: x86_64
# ======================================== CPU Info ========================================
# Physical cores: 4
# Total cores: 8
# Max Frequency: 3800.00Mhz
# Min Frequency: 800.00Mhz
# Current Frequency: 2659.85Mhz
# CPU Usage Per Core:
# Core 0: 0.0%
# Core 1: 0.0%
# Core 2: 0.0%
# Core 3: 1.0%
# Core 4: 2.0%
# Core 5: 2.0%
# Core 6: 1.0%
# Core 7: 0.0%
# Total CPU Usage: 2.0%
# ======================================== Memory Information ========================================
# Total: 15.51GB
# Available: 6.02GB
# Used: 9.17GB
# Percentage: 61.2%
# ==================== SWAP ====================
# Total: 4.00GB
# Free: 4.00GB
# Used: 0.00B
# Percentage: 0.0%
# ======================================== Disk Information ========================================
# Partitions and Usage:
# === Device: rpool/ROOT/ubuntu_5yt3ta ===
#   Mountpoint: /
#   File system type: zfs
#   Total Size: 283.15GB
#   Used: 4.43GB
#   Free: 278.72GB
#   Percentage: 1.6%
# === Device: rpool/ROOT/ubuntu_5yt3ta/srv ===
#   Mountpoint: /srv
#   File system type: zfs
#   Total Size: 278.72GB
#   Used: 128.00KB
#   Free: 278.72GB
#   Percentage: 0.0%
# === Device: rpool/ROOT/ubuntu_5yt3ta/usr/local ===
#   Mountpoint: /usr/local
#   File system type: zfs
#   Total Size: 278.72GB
#   Used: 256.00KB
#   Free: 278.72GB
#   Percentage: 0.0%
# === Device: rpool/ROOT/ubuntu_5yt3ta/var/games ===
#   Mountpoint: /var/games
#   File system type: zfs
#   Total Size: 278.72GB
#   Used: 128.00KB
#   Free: 278.72GB
#   Percentage: 0.0%
# === Device: rpool/ROOT/ubuntu_5yt3ta/var/lib ===
#   Mountpoint: /var/lib
#   File system type: zfs
#   Total Size: 428.30GB
#   Used: 149.58GB
#   Free: 278.72GB
#   Percentage: 34.9%
# === Device: rpool/ROOT/ubuntu_5yt3ta/var/lib/AccountsService ===
#   Mountpoint: /var/lib/AccountsService
#   File system type: zfs
#   Total Size: 278.72GB
#   Used: 128.00KB
#   Free: 278.72GB
#   Percentage: 0.0%
# === Device: rpool/ROOT/ubuntu_5yt3ta/var/lib/NetworkManager ===
#   Mountpoint: /var/lib/NetworkManager
#   File system type: zfs
#   Total Size: 278.72GB
#   Used: 256.00KB
#   Free: 278.72GB
#   Percentage: 0.0%
# === Device: rpool/ROOT/ubuntu_5yt3ta/var/lib/apt ===
#   Mountpoint: /var/lib/apt
#   File system type: zfs
#   Total Size: 278.80GB
#   Used: 81.38MB
#   Free: 278.72GB
#   Percentage: 0.0%
# === Device: rpool/ROOT/ubuntu_5yt3ta/var/lib/dpkg ===
#   Mountpoint: /var/lib/dpkg
#   File system type: zfs
#   Total Size: 278.76GB
#   Used: 38.50MB
#   Free: 278.72GB
#   Percentage: 0.0%
# === Device: rpool/ROOT/ubuntu_5yt3ta/var/log ===
#   Mountpoint: /var/log
#   File system type: zfs
#   Total Size: 281.69GB
#   Used: 2.97GB
#   Free: 278.72GB
#   Percentage: 1.1%
# === Device: rpool/ROOT/ubuntu_5yt3ta/var/mail ===
#   Mountpoint: /var/mail
#   File system type: zfs
#   Total Size: 278.72GB
#   Used: 128.00KB
#   Free: 278.72GB
#   Percentage: 0.0%
# === Device: rpool/ROOT/ubuntu_5yt3ta/var/snap ===
#   Mountpoint: /var/snap
#   File system type: zfs
#   Total Size: 278.72GB
#   Used: 1.38MB
#   Free: 278.72GB
#   Percentage: 0.0%
# === Device: rpool/ROOT/ubuntu_5yt3ta/var/spool ===
#   Mountpoint: /var/spool
#   File system type: zfs
#   Total Size: 278.72GB
#   Used: 128.00KB
#   Free: 278.72GB
#   Percentage: 0.0%
# === Device: rpool/ROOT/ubuntu_5yt3ta/var/www ===
#   Mountpoint: /var/www
#   File system type: zfs
#   Total Size: 278.72GB
#   Used: 128.00KB
#   Free: 278.72GB
#   Percentage: 0.0%
# === Device: rpool/USERDATA/root_k7v4ke ===
#   Mountpoint: /root
#   File system type: zfs
#   Total Size: 278.72GB
#   Used: 768.00KB
#   Free: 278.72GB
#   Percentage: 0.0%
# === Device: rpool/USERDATA/home_k7v4ke ===
#   Mountpoint: /home
#   File system type: zfs
#   Total Size: 296.35GB
#   Used: 17.63GB
#   Free: 278.72GB
#   Percentage: 5.9%
# === Device: bpool/BOOT/ubuntu_5yt3ta ===
#   Mountpoint: /boot
#   File system type: zfs
#   Total Size: 1.75GB
#   Used: 185.12MB
#   Free: 1.57GB
#   Percentage: 10.3%
# === Device: /dev/nvme0n1p1 ===
#   Mountpoint: /boot/efi
#   File system type: vfat
#   Total Size: 1.05GB
#   Used: 6.14MB
#   Free: 1.04GB
#   Percentage: 0.6%
# === Device: /dev/loop0 ===
#   Mountpoint: /snap/bare/5
#   File system type: squashfs
#   Total Size: 128.00KB
#   Used: 128.00KB
#   Free: 0.00B
#   Percentage: 100.0%
# === Device: /dev/loop1 ===
#   Mountpoint: /snap/core22/1663
#   File system type: squashfs
#   Total Size: 73.88MB
#   Used: 73.88MB
#   Free: 0.00B
#   Percentage: 100.0%
# === Device: /dev/loop2 ===
#   Mountpoint: /snap/core22/1722
#   File system type: squashfs
#   Total Size: 73.88MB
#   Used: 73.88MB
#   Free: 0.00B
#   Percentage: 100.0%
# === Device: /dev/loop3 ===
#   Mountpoint: /snap/firefox/5361
#   File system type: squashfs
#   Total Size: 274.12MB
#   Used: 274.12MB
#   Free: 0.00B
#   Percentage: 100.0%
# === Device: /dev/loop4 ===
#   Mountpoint: /snap/firefox/5437
#   File system type: squashfs
#   Total Size: 273.75MB
#   Used: 273.75MB
#   Free: 0.00B
#   Percentage: 100.0%
# === Device: /dev/loop5 ===
#   Mountpoint: /snap/firmware-updater/127
#   File system type: squashfs
#   Total Size: 10.75MB
#   Used: 10.75MB
#   Free: 0.00B
#   Percentage: 100.0%
# === Device: /dev/loop6 ===
#   Mountpoint: /snap/firmware-updater/147
#   File system type: squashfs
#   Total Size: 11.12MB
#   Used: 11.12MB
#   Free: 0.00B
#   Percentage: 100.0%
# === Device: /dev/loop7 ===
#   Mountpoint: /snap/gnome-42-2204/176
#   File system type: squashfs
#   Total Size: 505.12MB
#   Used: 505.12MB
#   Free: 0.00B
#   Percentage: 100.0%
# === Device: /dev/loop8 ===
#   Mountpoint: /snap/gtk-common-themes/1535
#   File system type: squashfs
#   Total Size: 91.75MB
#   Used: 91.75MB
#   Free: 0.00B
#   Percentage: 100.0%
# === Device: /dev/loop9 ===
#   Mountpoint: /snap/snap-store/1244
#   File system type: squashfs
#   Total Size: 10.88MB
#   Used: 10.88MB
#   Free: 0.00B
#   Percentage: 100.0%
# === Device: /dev/loop10 ===
#   Mountpoint: /snap/snap-store/1248
#   File system type: squashfs
#   Total Size: 10.88MB
#   Used: 10.88MB
#   Free: 0.00B
#   Percentage: 100.0%
# === Device: /dev/loop11 ===
#   Mountpoint: /snap/snapd/21759
#   File system type: squashfs
#   Total Size: 38.88MB
#   Used: 38.88MB
#   Free: 0.00B
#   Percentage: 100.0%
# === Device: /dev/loop12 ===
#   Mountpoint: /snap/snapd/23258
#   File system type: squashfs
#   Total Size: 44.38MB
#   Used: 44.38MB
#   Free: 0.00B
#   Percentage: 100.0%
# === Device: /dev/loop14 ===
#   Mountpoint: /snap/snapd-desktop-integration/247
#   File system type: squashfs
#   Total Size: 640.00KB
#   Used: 640.00KB
#   Free: 0.00B
#   Percentage: 100.0%
# === Device: /dev/loop13 ===
#   Mountpoint: /snap/snapd-desktop-integration/253
#   File system type: squashfs
#   Total Size: 640.00KB
#   Used: 640.00KB
#   Free: 0.00B
#   Percentage: 100.0%
# Total read: 1.82GB
# Total write: 37.66GB
# ======================================== Network Information ========================================
# === Interface: lo ===
# === Interface: lo ===
# === Interface: lo ===
# === Interface: enp0s31f6 ===
# === Interface: enp0s31f6 ===
# === Interface: enp0s31f6 ===
# === Interface: ztklhquq5s ===
# === Interface: ztklhquq5s ===
# === Interface: ztklhquq5s ===
# === Interface: docker0 ===
# === Interface: docker0 ===
# === Interface: docker0 ===
# === Interface: br-a7cdc13b0c44 ===
# === Interface: br-a7cdc13b0c44 ===
# === Interface: br-0a9cc987d4df ===
# === Interface: br-0a9cc987d4df ===
# === Interface: br-0a9cc987d4df ===
# === Interface: veth50b39d6 ===
# === Interface: veth50b39d6 ===
# === Interface: veth689eaef ===
# === Interface: veth689eaef ===
# === Interface: veth0aabd88 ===
# === Interface: veth0aabd88 ===
# === Interface: veth75a1478 ===
# === Interface: veth75a1478 ===
# === Interface: vethde9ee11 ===
# === Interface: vethde9ee11 ===
# === Interface: vethd6d998a ===
# === Interface: vethd6d998a ===
# Total Bytes Sent: 39.94GB
# Total Bytes Received: 39.90GB

# %%
import logging
logging.getLevelNamesMapping()
list(logging.getLevelNamesMapping())
# logging.getLevelNamesMapping()['DEBUG']
# Out:
# ['CRITICAL', 'FATAL', 'ERROR', 'WARN', 'WARNING', 'INFO', 'DEBUG', 'NOTSET']
